# %% [markdown]
# # Lab Report 1

# %% [markdown]
# The purpose of this experiment is to get familiar with the instruments we will be using throughout this course as well as learning and practicing length, mass, and volume measurements. The cause of this experiment is to also become more proficient in our time keeping and conversions of all measurements that are being documented.

# %% [markdown]
# The materials used during this experiment consisted of a ruler, beaker, graduated cylinder, a scale, water, a book, a phone, pH strips, three test tubes and three testing solutions. For linear measurements we used the cm side of our ruler to measure the length, width, and depth of our book. We then wrote down the results in cm. and converted them to mm. measurements. For our volume measurements we poured some water in a beaker and recorded the volume in ml and converted that number to liters. We continued to pour the water from the beaker into a graduated cylinder and recorded the volume from ml and converted into liters again. We set aside this part of the experiment to use for our mass measurement portion. For mass measurements we put a phone on the scale and recorded the mass of the weight in grams and then converted the mass to mg. From the graduated cylinder that still had previously we poured some water into the beaker and placed it on the scale. We measured the mass of the liquid in grams and converted that number into mg. For our pH measurements we had three testing tubes labeled A,B, and C. We then put three different solutions in each of the tubes. We then placed a pH testing strip in each one of the tubes and observed the color change. From the color we were able to identify the level of pH for each solution. For time measurement we had to identify our pulse rate after 15 seconds and 60 seconds. We converted our beats per minute to beats per second, to beats per millisecond.

# %% [markdown]
# ![ADD8CE58-2196-4673-9E79-BCB5BB819842_1_201_a.jpeg](attachment:ADD8CE58-2196-4673-9E79-BCB5BB819842_1_201_a.jpeg)

# %% [markdown]
# After collecting the data above we were able to covert centimeters to millimeters by multiplying the centimeter result by 10. For volume measurements we were able to divide the ml result by 1000 to convert it into liters. We did that same conversion for our mass measurements. When it came to pH measurements you eye the color of the strip and that color helps identify what the balance of the pH is. Time measurement you can take your beats per minute and divide that by 60 in order to get results for seconds and then continue to multiply that number by 1000 to get your answer for milliseconds. An experimental error that could have occurred is when taking my pulse rate I did use a smart watch instead of the black box. I would recommend using the black box for more of an accurate result of pulse rate. I believe another experimental error that could have occured during taking my pulse rate was not being very accurate on my timing after taking my pulse for 15 seconds and then for another 60 seconds. I would say it might be wiser to have a timer to make sure you're measuring the accurate time as well.

# %% [markdown]
# The purpose of this experiment was to familiarize ourselves with the intruments of the lab and to learn how to measure time, mass, volume, and length. After analyzing the data collected I can see there were a lot of common patterns to converting numbers. I was also able to observe all the different types of measurements that can be made through time, mass, volume, and length. During the experiment I was able to become familiar with the different instruments in the lab that are going to be used throughout this course.
